# %% [markdown]
# <a href="https://colab.research.google.com/github/srenisureneni/INFO-5731/blob/master/Term_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import tweepy as tw
import pandas as pd

consumer_key = 'qWaI6kizU7SAcRNc6EnnoNChq'
consumer_secret = 'xumE7NgIZMiLCUXFeEl0pr3zhsuqdLvOPB0tG94HBQ8PgP2vsK'
access_token = '2747565082-8g1OYC9aFI4NxRInAV5ArxV1te4V6alDLHlQuNn'
access_token_secret = 'rDMmFApw3H5vL5KqVRxwRKdmJCkRdmrqjG8CCfmVroNKV'

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth)

# %%
tweet_id = pd.read_csv(r"corpus.csv")
dict_id = tweet_id.set_index('ID').T.to_dict('list')
print(dict_id)
ids = tweet_id['ID'].tolist()
senti = tweet_id['Sentiment'].tolist()

def tweet_text(ids):
    tweet_status_list = api.statuses_lookup(ids)
    #print(tweet_status_list)
    text = list()
    dict_tot = {}
    for status in tweet_status_list:
            dict_tot[status.id] = [status.text,dict_id[status.id][0]]
            tweet_text = {"tweet":status.text}
            text.append(tweet_text["tweet"])
            #print(dict_tot)
    return text, dict_tot


ids_count = len(ids)
batches = (ids_count - 1) // 50 + 1
senti_batch =  {}
#print(batches)
tot_list = []
def Merge(dict1, dict2):
    res = {**dict1, **dict2}
    return res
for i in range(batches):
        batch = ids[i*50:(i+1)*50]
        resu, dict_tot= tweet_text(batch)
        senti_batch.update(dict_tot)

print(senti_batch)
# Out:
# {126415614616154000: ['positive'], 126404574230740000: ['positive'], 126402758403305000: ['positive'], 126397179614068000: ['positive'], 126395626979196000: ['positive'], 126394830791254000: ['positive'], 126379685453119000: ['positive'], 126377656416612000: ['positive'], 126373779483004000: ['positive'], 126366353757179000: ['positive'], 126366123368267000: ['positive'], 126365858481188000: ['positive'], 126360935509135000: ['positive'], 126360398885687000: ['positive'], 126358340220616000: ['positive'], 126357982685569000: ['positive'], 126354605130002000: ['positive'], 126352268705538000: ['positive'], 126350948548354000: ['positive'], 126350302113824000: ['positive'], 126349695676203000: ['positive'], 126344048637259000: ['positive'], 126342268603998000: ['positive'], 126325800080392000: ['positive'], 126324177501302000: ['positive'], 126323785145126000: ['positive'], 126322063332999000: ['positive'], 126319186141130000: ['positive'], 126318009647235000: ['positive'], 12631522306
# ...
